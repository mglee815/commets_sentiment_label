# %%
import pandas as pd
comments_data = pd.read_csv("../data/replaced_text.csv")
temp = comments_data.sample(frac=1).reset_index(drop=True)
temp['text'] = temp['text'].apply(lambda x : x.replace('\n', ' '))
temp['text'] = temp['text'].apply(lambda x : x.replace('\t', ' '))
temp['replaced text'] = temp['replaced text'].apply(lambda x : x.replace('\n' , ' '))
temp['replaced text'] = temp['replaced text'].apply(lambda x : x.replace('\t' , ' '))
train_test = temp
train_test['감정'] = temp['감정'].apply(lambda x: 1 if x == '긍정' else 0)

# %%
train_test
# Out:
#       Unnamed: 0                                               text        타겟  \
# 0           2750                                      재밌나? 예능을 안 봐서  NO_TOKEN
# 1           2773                               노홍철 넷플릭스외치는거 너무싫어요ㅜㅜ       노홍철
# 2           1617  전 국민이 이핵관이 되자.  이핵관이 이재명이하고 같이  크게 해먹자.   나라가 ...  이핵관, 이재명
# 3           1640                                            후보교체뿐이다  NO_TOKEN
# 4            955                미친... 불법인게 드러났으면 입학취소에 면허도 취소되야지...  NO_TOKEN
# ...          ...                                                ...       ...
# 3495         192  철저하게 세뇌되어가는 개돼지들 ~~~ 우리나라 민도수준 이 정도밖에는 안되는것인가 ...       개돼지
# 3496         647                         대가 중요하면 그런거 다감안하고 결혼결정했어야지  NO_TOKEN
# 3497        1316  댓글을 보니 야권분열의 공작이 드러나고 있다..절대 속지 말자 정권을고체해 근혜의 ...        댓글
# 3498         173            다분히 대선 표를 의식한 행위내 그런다고 니들이 정권 유지가 될것 같냐        정권
# 3499         455                            인간의 자유권 위에 감염예방법이 있나보네요  NO_TOKEN
#
#             대조  감정                                      replaced text
# 0     NO_TOKEN   0                                      재밌나? 예능을 안 봐서
# 1     NO_TOKEN   0                                타겟 넷플릭스외치는거 너무싫어요ㅜㅜ
# 2     NO_TOKEN   1  전 국민이 타겟이 되자.  타겟이타겟이하고 같이  크게 해먹자.   나라가 뭐냐? ...
# 3     NO_TOKEN   0                                            후보교체뿐이다
# 4     NO_TOKEN   0                미친... 불법인게 드러났으면 입학취소에 면허도 취소되야지...
# ...        ...  ..                                                ...
# 3495  NO_TOKEN   0  철저하게 세뇌되어가는 타겟들 ~~~ 우리나라 민도수준 이 정도밖에는 안되는것인가 ?...
# 3496  NO_TOKEN   0                         대가 중요하면 그런거 다감안하고 결혼결정했어야지
# 3497  NO_TOKEN   0  타겟을 보니 야권분열의 공작이 드러나고 있다..절대 속지 말자 정권을고체해 근혜의 ...
# 3498  NO_TOKEN   0            다분히 대선 표를 의식한 행위내 그런다고 니들이 타겟 유지가 될것 같냐
# 3499  NO_TOKEN   0                            인간의 자유권 위에 감염예방법이 있나보네요
#
# [3500 rows x 6 columns]

# %%
comments_train = train_test[:3000]
comments_test = train_test[3000:]

print(comments_train.shape[0])
print(comments_test.shape[0])
# Out:
# 3000
# 500

# %%
comments_train.to_csv('../data/comments_train.tsv', index=False, header=True, sep = "\t")
comments_test.to_csv('../data/comments_test.tsv', index=False, header=True, sep = "\t")
